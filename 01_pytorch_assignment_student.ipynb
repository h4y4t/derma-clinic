# %% [markdown]
# # PyTorch Fundamentals - Assignment 1
#
# <a target="_blank" href="https://colab.research.google.com/github/sham-nlp/2026nlp-1-pytorch-fundamentals/blob/main/01_pytorch_assignment_student.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# **Name:** `Hayat Koujan`
#
#
# **Date:** `8/3/2026` 'sorry for being late'
#
# ---
#
# ## Instructions
#
# Complete the code sections marked with `# YOUR CODE HERE`.
#
# **Submission:** Submit this notebook with all cells executed and outputs visible.

# %% [markdown]
# ---
#
# ## Part 1: Tensor Basics

# %%
import torch

# TODO: Create a 2x3 tensor with values 1 through 6
# Hint: Use torch.tensor() or torch.arange() with .reshape()
x = x = torch.arange(1, 7).reshape(2, 3)

print("Tensor x:")
print(x)
print()

print(f"Shape:   {x.shape}")      # Expected: torch.Size([2, 3])
print(f"Dtype:   {x.dtype}")      # Expected: torch.int64
print(f"Device:  {x.device}")     # Expected: cpu
print(f"Stride:  {x.stride()}")   # Expected: (3, 1)
print(f"Is contiguous: {x.is_contiguous()}")  # Expected: True
# Out:
# Tensor x:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
#
# Shape:   torch.Size([2, 3])
# Dtype:   torch.int64
# Device:  cpu
# Stride:  (3, 1)
# Is contiguous: True

# %%
# TODO: Create the same tensor but with dtype float32
# Hint: Pass dtype=torch.float32 to torch.tensor(..., dtype=torch.float32)
x_float =x_float = torch.arange(1, 7, dtype=torch.float32).reshape(2, 3)

print(f"Float tensor dtype: {x_float.dtype}")  # Expected: torch.float32
# Out:
# Float tensor dtype: torch.float32

# %% [markdown]
# ---
#
# ## Part 2: Building a Linear Model
#
# Implement y = wx + b using PyTorch tensors with gradient tracking.

# %%
# Input: negative news ratio
x = torch.tensor([[0.3], [0.7], [0.1], [0.5]])

# Target: exchange rate increases
y_true = torch.tensor([[12.0], [29.0], [4.0], [23.0]])

print(f"Input shape:  {x.shape}")    # (4, 1) - 4 samples, 1 feature
print(f"Target shape: {y_true.shape}")  # (4, 1) - 4 samples, 1 output

# TODO: Initialize weight w and bias b
# Use requires_grad=True so PyTorch tracks gradients
# Initialize w to 0.5 and b to 0.0
w = torch.tensor([[0.5]], requires_grad=True)
b = torch.tensor([[0.0]], requires_grad=True)

print(f"\nInitial w: {w.item():.2f}")  # Expected: 0.50
print(f"Initial b: {b.item():.2f}")  # Expected: 0.00
# Out:
# Input shape:  torch.Size([4, 1])
# Target shape: torch.Size([4, 1])
#
# Initial w: 0.50
# Initial b: 0.00

# %%
# TODO: Define the forward function: y_pred = x @ w + b
def forward(x, w, b):
   return x @ w.T + b

# Test it
y_pred = forward(x, w, b)
print("Predictions with initial w, b:")
print(y_pred)
# Out:
# Predictions with initial w, b:
# tensor([[0.1500],
#         [0.3500],
#         [0.0500],
#         [0.2500]], grad_fn=<AddBackward0>)

# %% [markdown]
# ---
#
# ## Part 3: Loss and Gradients

# %%
# TODO: Define MSE loss function
def mse_loss(y_pred, y_true):
    return ((y_pred - y_true) ** 2).mean()

# Compute loss
loss = mse_loss(y_pred, y_true)
print(f"Initial loss: {loss.item():.2f}")

# TODO: Compute gradients using autograd
# Hint: Call something on the loss [ loss.???() ]

loss.backward()


print(f"\nGradients computed!")
print(f"dw (gradient of loss w.r.t. w): {w.grad.item():.2f}")
print(f"db (gradient of loss w.r.t. b): {b.grad.item():.2f}")
# Out:
# Initial loss: 373.60
#
# Gradients computed!
# dw (gradient of loss w.r.t. w): -17.69
# db (gradient of loss w.r.t. b): -33.60

# %% [markdown]
# ---
#
# ## Part 4: Manual Gradient Descent

# %%
learning_rate = 0.1

# TODO: Update parameters using gradient descent
# w_new = w_old - learning_rate * gradient
# Use torch.no_grad() context so this update isn't tracked
with torch.no_grad():
   w -= learning_rate * w.grad
   b -= learning_rate * b.grad
# TODO: Zero the gradients for next iteration
# Hint: Set .grad to ???
w.grad = None
b.grad = None

print(f"After one update:")
print(f"w: {w.item():.4f}")
print(f"b: {b.item():.4f}")

# Check new predictions
y_pred_new = forward(x, w, b)
loss_new = mse_loss(y_pred_new, y_true)
print(f"\nNew loss: {loss_new.item():.2f}")
print(f"Old loss: {loss.item():.2f}")
print(f"Loss decreased? {loss_new < loss}")
# Out:
# After one update:
# w: 2.2690
# b: 3.3600
#
# New loss: 246.11
# Old loss: 373.60
# Loss decreased? True

# %% [markdown]
# ---
#
# ## Part 5: Full Training Loop

# %%
# Reset parameters
w = torch.tensor([[0.5]], requires_grad=True)
b = torch.tensor([0.0], requires_grad=True)

learning_rate = 0.1
epochs = 1000

for epoch in range(epochs):
    # Step 1: Forward pass
    y_pred = forward(x, w, b)

    # Step 2: Compute loss
    loss = mse_loss(y_pred, y_true)

    # Step 3: Backward pass
    loss.backward()

    # Step 4: Update parameters
    with torch.no_grad():
        w -= learning_rate * w.grad
        b -= learning_rate * b.grad


    # Step 5: Zero gradients
    w.grad = None
    b.grad = None
    # Print progress every 100 epochs
    if (epoch + 1) % 100 == 0:
        print(f"Epoch {epoch+1:4d} | Loss: {loss.item():.6f} | w: {w.item():.4f} | b: {b.item():.4f}")

print("\n" + "="*50)
print("Training complete!")
print(f"Final w: {w.item():.4f} (expected: ~40.0)")
print(f"Final b: {b.item():.4f} (expected: ~0.0)")
print(f"Final loss: {mse_loss(forward(x, w, b), y_true).item():.6f}")
# Out:
# Epoch  100 | Loss: 13.086384 | w: 27.6666 | b: 6.2079
# Epoch  200 | Loss: 3.203285 | w: 36.5145 | b: 2.5103
# Epoch  300 | Loss: 1.435218 | w: 40.2569 | b: 0.9464
# Epoch  400 | Loss: 1.118915 | w: 41.8398 | b: 0.2849
# Epoch  500 | Loss: 1.062328 | w: 42.5093 | b: 0.0051
# Epoch  600 | Loss: 1.052206 | w: 42.7924 | b: -0.1133
# Epoch  700 | Loss: 1.050395 | w: 42.9122 | b: -0.1633
# Epoch  800 | Loss: 1.050071 | w: 42.9629 | b: -0.1845
# Epoch  900 | Loss: 1.050013 | w: 42.9843 | b: -0.1934
# Epoch 1000 | Loss: 1.050002 | w: 42.9934 | b: -0.1972
#
# ==================================================
# Training complete!
# Final w: 42.9934 (expected: ~40.0)
# Final b: -0.1972 (expected: ~0.0)
# Final loss: 1.050003

# %% [markdown]
# ---
#
# ## Part 6: Test Your Model

# %%
# TODO: Make a prediction for 0.1 news ratio
test_input = torch.tensor([[0.1]])
prediction = forward(test_input, w, b)
print(f"Predicted exchange rate increase: {prediction.item():.2f}%")
# Out:
# Predicted exchange rate increase: 4.10%

# %% [markdown]
# ---
#
# ## Part 7: Training with `nn.Linear` and Manual SGD

# %%
import torch.nn as nn

x = torch.tensor([[0.3], [0.7], [0.1], [0.5]])
y_true = torch.tensor([[12.0], [29.0], [4.0], [23.0]])

# TODO: Create an nn.Linear layer with 1 input and 1 output
# Hint: nn.Linear(in_features, out_features)
model = nn.Linear(1, 1)

print(f"Model: {model}")
print(f"Initial weight: {model.weight.item():.4f}")  # Random value
print(f"Initial bias: {model.bias.item():.4f}")    # Random value
# Out:
# Model: Linear(in_features=1, out_features=1, bias=True)
# Initial weight: -0.2383
# Initial bias: -0.3255

# %% [markdown]
# ---
#
# ### Method 1: Update Each Parameter Directly
#
# Update `model.weight` and `model.bias` separately.

# %%
learning_rate = 0.01
epochs = 500

print("Training with Method 1: Direct parameter update\n")
print(f"{'Epoch':>6} | {'Loss':>10} | {'Weight':>8} | {'Bias':>8}")
print("-" * 42)

for epoch in range(epochs):
    # Step 1: Forward pass
    y_pred = model(x)

    # Step 2: Compute loss
    loss = mse_loss(y_pred, y_true)

    # Step 3: Backward pass
    loss.backward()

    # Step 4: Update parameters (IMPORTANT: use torch.no_grad()!)
    # Hint: model.weight -= learning_rate * model.weight.grad
    #       same for bias
    with torch.no_grad():
        model.weight -= learning_rate * model.weight.grad
        model.bias   -= learning_rate * model.bias.grad

    # Step 5: Zero the gradients
    # Hint: model.weight.grad.zero_()
    #       model.bias.grad.zero_()
    model.weight.grad.zero_()
    model.bias.grad.zero_()

    # Print progress every 50 epochs
    if (epoch + 1) % 50 == 0:
        print(f"{epoch+1:6d} | {loss.item():10.6f} | {model.weight.item():8.4f} | {model.bias.item():8.4f}")

print("\n" + "="*42)
print(f"Final weight: {model.weight.item():.4f} (expected: ~4.0)")
print(f"Final bias:   {model.bias.item():.4f} (expected: ~0.0)")
# Out:
# Training with Method 1: Direct parameter update
#
#  Epoch |       Loss |   Weight |     Bias
# ------------------------------------------
#     50 |  96.083321 |   5.7902 |   9.7648
#    100 |  61.511940 |   8.6450 |  12.4425
#    150 |  54.023239 |  10.4834 |  12.8625
#    200 |  49.434147 |  11.9694 |  12.6062
#    250 |  45.437302 |  13.3086 |  12.1585
#    300 |  41.789040 |  14.5657 |  11.6675
#    350 |  38.442387 |  15.7621 |  11.1781
#    400 |  35.370815 |  16.9059 |  10.7034
#    450 |  32.551559 |  18.0009 |  10.2467
#    500 |  29.963905 |  19.0498 |   9.8087
#
# ==========================================
# Final weight: 19.0498 (expected: ~4.0)
# Final bias:   9.8087 (expected: ~0.0)

# %% [markdown]
# ---
#
# ### Method 2: Update Using `model.parameters()`
#
# Loop through all parameters automatically - more scalable for larger models!

# %%
model = nn.Linear(1, 1)

learning_rate = 0.01
epochs = 500

print("Training with Method 2: Using model.parameters()\n")
print(f"{'Epoch':>6} | {'Loss':>10} | {'Weight':>8} | {'Bias':>8}")
print("-" * 42)

for epoch in range(epochs):
    # Step 1: Forward pass
    y_pred = model(x)

    # Step 2: Compute loss
    loss = ((y_pred - y_true) ** 2).mean()

    # Step 3: Backward pass
    loss.backward()

    # Step 4: Update parameters using model.parameters()
    # This loops through BOTH weight and bias automatically!
    # Hint: for param in model.parameters():
    #           param -= learning_rate * param.grad
    with torch.no_grad():
             for param in model.parameters():
              param -= learning_rate * param.grad

    # Step 5: Zero the gradients using model.parameters()
    # Hint: for param in model.parameters():
    #           param.grad.zero_()
    for param in model.parameters():
        param.grad.zero_()

    # Print progress every 50 epochs
    if (epoch + 1) % 50 == 0:
        print(f"{epoch+1:6d} | {loss.item():10.6f} | {model.weight.item():8.4f} | {model.bias.item():8.4f}")

print("\n" + "="*42)
print(f"Final weight: {model.weight.item():.4f} (expected: ~4.0)")
print(f"Final bias:   {model.bias.item():.4f} (expected: ~0.0)")
# Out:
# Training with Method 2: Using model.parameters()
#
#  Epoch |       Loss |   Weight |     Bias
# ------------------------------------------
#     50 |  99.000267 |   5.6430 |   9.6006
#    100 |  61.982712 |   8.5562 |  12.4103
#    150 |  54.247425 |  10.4144 |  12.8700
#    200 |  49.620327 |  11.9082 |  12.6252
#    250 |  45.606331 |  13.2515 |  12.1804
#    300 |  41.944008 |  14.5115 |  11.6896
#    350 |  38.584599 |  15.7103 |  11.1996
#    400 |  35.501335 |  16.8563 |  10.7240
#    450 |  32.671379 |  17.9534 |  10.2666
#    500 |  30.073875 |  19.0043 |   9.8277
#
# ==========================================
# Final weight: 19.0043 (expected: ~4.0)
# Final bias:   9.8277 (expected: ~0.0)

# %% [markdown]
# ---
#
# ## Part 8: Challenge (Optional)
#
# Explore what happens with a different relationship.
#
# Generate data where y = 2x² + 3x + 1 and try to fit it.
#
# Hint: You'll need to create features [x, x²] and use a weight vector with 2 elements.

# %%
import torch
import torch.nn as nn

# Step 1: Generate x values
x_raw = torch.linspace(-2, 2, 50).reshape(-1, 1)  # shape (50, 1)

# Step 2: Compute true y = 2x² + 3x + 1
y_true = 2 * x_raw**2 + 3 * x_raw + 1             # shape (50, 1)

# Step 3: Create feature matrix [x, x²] — shape (50, 2)
x_features = torch.cat([x_raw, x_raw**2], dim=1)

# Step 4: Model — 2 inputs (x and x²), 1 output
model = nn.Linear(2, 1)

# Step 5: Training loop
learning_rate = 0.01
epochs = 1000

print(f"{'Epoch':>6} | {'Loss':>12} | {'w1 (x)':>10} | {'w2 (x²)':>10} | {'bias':>8}")
print("-" * 58)

for epoch in range(epochs):
    # Forward pass
    y_pred = model(x_features)

    # Loss
    loss = ((y_pred - y_true) ** 2).mean()

    # Backward
    loss.backward()

    # Update
    with torch.no_grad():
        for param in model.parameters():
            param -= learning_rate * param.grad

    # Zero gradients
    for param in model.parameters():
        param.grad.zero_()

    if (epoch + 1) % 100 == 0:
        w1, w2 = model.weight[0]
        print(f"{epoch+1:6d} | {loss.item():12.6f} | {w1.item():10.4f} | {w2.item():10.4f} | {model.bias.item():8.4f}")

print("\n" + "="*58)
print("Expected: w1 (x) ≈ 3.0 | w2 (x²) ≈ 2.0 | bias ≈ 1.0")
print(f"Got:      w1 (x) = {model.weight[0][0].item():.4f} | "
      f"w2 (x²) = {model.weight[0][1].item():.4f} | "
      f"bias = {model.bias.item():.4f}")

# Test a single prediction
test_x = torch.tensor([[1.0, 1.0]])   # x=1, x²=1
pred = model(test_x)
actual = 2*(1)**2 + 3*(1) + 1         # = 6.0
print(f"\nAt x=1: predicted={pred.item():.4f}, actual={actual:.4f}")
# Out:
#  Epoch |         Loss |     w1 (x) |    w2 (x²) |     bias
# ----------------------------------------------------------
#    100 |     0.045761 |     2.8266 |     2.0265 |   0.9401
#    200 |     0.000520 |     2.9896 |     2.0126 |   0.9719
#    300 |     0.000080 |     2.9994 |     2.0059 |   0.9868
#    400 |     0.000018 |     3.0000 |     2.0028 |   0.9938
#    500 |     0.000004 |     3.0000 |     2.0013 |   0.9971
#    600 |     0.000001 |     3.0000 |     2.0006 |   0.9986
#    700 |     0.000000 |     3.0000 |     2.0003 |   0.9994
#    800 |     0.000000 |     3.0000 |     2.0001 |   0.9997
#    900 |     0.000000 |     3.0000 |     2.0001 |   0.9999
#   1000 |     0.000000 |     3.0000 |     2.0000 |   0.9999
#
# ==========================================================
# Expected: w1 (x) ≈ 3.0 | w2 (x²) ≈ 2.0 | bias ≈ 1.0
# Got:      w1 (x) = 3.0000 | w2 (x²) = 2.0000 | bias = 0.9999
#
# At x=1: predicted=6.0000, actual=6.0000
